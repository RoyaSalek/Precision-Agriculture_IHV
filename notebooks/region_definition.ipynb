# %% [markdown]
# Goal:
# Define what constitutes an anomaly region in vineyard imagery.
#
# Question:
# - What is a region?
# - How large should a region be?
# - What imagery is required?
# - How should regions be labeled?
# - What confidence level is needed before escalattion to a human?

# %%
from pathlib import Path
print(Path.cwd())
# Out:
# /Users/willm/Active Projects/precision_agriculture/notebooks

# %% [markdown]
# # Region Definition Research
#
# ## Current Understanding
#
# We are not attempting to diagnose vineyard issues.
#
# We are attempting to identify areas that warrant human inspection.
#
# Examples:
# - Brown foliage
# - Missing foliage
# - Unusual coloration
# - Irrigation irregularities
# - Unknown visual abnormalities
#
# ## Open Questions
#
# 1. What physical size should a region represent?
# 2. How should regions be labeled?
# 3. What imagery is required?
# 4. How much training data is needed?
# 5. How will regions be displayed in the mobile visualization tool?
